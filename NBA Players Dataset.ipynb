# %%
# Import necessary libraries
import pandas as pd

# Load dataset
file_path = 'all_seasons.csv'
dataset = pd.read_csv(file_path)

# Data exploration
print("Shape of the dataset:", dataset.shape)
print("Columns:", dataset.columns.tolist())
print("Data Types:")
print(dataset.dtypes)
print("Missing Values:")
print(dataset.isnull().sum())
print("Summary Statistics:")
print(dataset.describe(include='all'))
# Out:
# Shape of the dataset: (12844, 22)
# Columns: ['player_id', 'player_name', 'team_abbreviation', 'age', 'player_height', 'player_weight', 'college', 'country', 'draft_year', 'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating', 'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season']
# Data Types:
# player_id              int64
# player_name           object
# team_abbreviation     object
# age                    int64
# player_height        float64
# player_weight        float64
# college               object
# country               object
# draft_year            object
# draft_round           object
# draft_number          object
# gp                     int64
# pts                  float64
# reb                  float64
# ast                  float64
# net_rating           float64
# oreb_pct             float64
# dreb_pct             float64
# usg_pct              float64
# ts_pct               float64
# ast_pct              float64
# season                object
# dtype: object
# Missing Values:
# player_id            0
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# player_weight        0
# college              0
# country              0
# draft_year           0
# draft_round          0
# draft_number         0
# gp                   0
# pts                  0
# reb                  0
# ast                  0
# net_rating           0
# oreb_pct             0
# dreb_pct             0
# usg_pct              0
# ts_pct               0
# ast_pct              0
# season               0
# dtype: int64
# Summary Statistics:
#            player_id   player_name team_abbreviation           age  \
# count   12844.000000         12844             12844  12844.000000
# unique           NaN          2551                36           NaN
# top              NaN  Vince Carter               CLE           NaN
# freq             NaN            22               450           NaN
# mean     6421.500000           NaN               NaN     27.045313
# std      3707.887763           NaN               NaN      4.339211
# min         0.000000           NaN               NaN     18.000000
# 25%      3210.750000           NaN               NaN     24.000000
# 50%      6421.500000           NaN               NaN     26.000000
# 75%      9632.250000           NaN               NaN     30.000000
# max     12843.000000           NaN               NaN     44.000000
#
#         player_height  player_weight college country draft_year draft_round  \
# count    12844.000000   12844.000000   12844   12844      12844       12844
# unique            NaN            NaN     357      82         48           9
# top               NaN            NaN    None     USA  Undrafted           1
# freq              NaN            NaN    1854   10721       2358        7351
# mean       200.555097     100.263279     NaN     NaN        NaN         NaN
# std          9.111090      12.426628     NaN     NaN        NaN         NaN
# min        160.020000      60.327736     NaN     NaN        NaN         NaN
# 25%        193.040000      90.718400     NaN     NaN        NaN         NaN
# 50%        200.660000      99.790240     NaN     NaN        NaN         NaN
# 75%        208.280000     108.862080     NaN     NaN        NaN         NaN
# max        231.140000     163.293120     NaN     NaN        NaN         NaN
#
#         ...           pts           reb           ast    net_rating  \
# count   ...  12844.000000  12844.000000  12844.000000  12844.000000
# unique  ...           NaN           NaN           NaN           NaN
# top     ...           NaN           NaN           NaN           NaN
# freq    ...           NaN           NaN           NaN           NaN
# mean    ...      8.212582      3.558486      1.824681     -2.226339
# std     ...      6.016573      2.477885      1.800840     12.665124
# min     ...      0.000000      0.000000      0.000000   -250.000000
# 25%     ...      3.600000      1.800000      0.600000     -6.400000
# 50%     ...      6.700000      3.000000      1.200000     -1.300000
# 75%     ...     11.500000      4.700000      2.400000      3.200000
# max     ...     36.100000     16.300000     11.700000    300.000000
#
#             oreb_pct      dreb_pct       usg_pct        ts_pct       ast_pct  \
# count   12844.000000  12844.000000  12844.000000  12844.000000  12844.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.054073      0.140646      0.184641      0.513138      0.131595
# std         0.043335      0.062513      0.053545      0.101724      0.094172
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.021000      0.096000      0.149000      0.482000      0.066000
# 50%         0.040000      0.130500      0.181000      0.525000      0.103000
# 75%         0.083000      0.179000      0.217000      0.563000      0.179000
# max         1.000000      1.000000      1.000000      1.500000      1.000000
#
#          season
# count     12844
# unique       27
# top     2021-22
# freq        605
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN
#
# [11 rows x 22 columns]
